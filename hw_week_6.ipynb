# %%
## import the pandas library in this cell
import pandas as pd

# %%
## import data and store in dataframe
pd.read_csv("data_raw/ems20_1st_6months_excerpt.csv")
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0            201101264  2020-04-19 10:25:47            INJMIN
# 1            200423766  2020-02-11 19:25:47              CARD
# 2            200434110  2020-02-12 21:36:52               UNC
# 3            201610121  2020-06-09 00:52:30              DRUG
# 4            200034112  2020-01-03 20:44:05              DRUG
# ...                ...                  ...               ...
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                                7          INJMIN                          7
# ...

# %%
## name dataframe
ems2020_excerpt_df = pd.read_csv("data_raw/ems20_1st_6months_excerpt.csv")

# %%
## call the last 5 rows
ems2020_excerpt_df.tail(5)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# 13116                            2          DIFFFC                          2
#
#       FIRST_ASSIGNMENT_DATETIME VALID_DISPATCH_RSPNS_TIME_INDC  \
# ...

# %%
## call a 20 random rows
ems2020_excerpt_df.sample(20)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 6502         200834992  2020-03-23 20:35:11            DIFFFC
# 11431        201793077  2020-06-27 18:58:03               EDP
# 446          201291216  2020-05-08 10:51:21              SICK
# 6418         200653957  2020-03-05 20:20:51            INJURY
# 8401         200193360  2020-01-19 19:14:27              SICK
# 3755         201363068  2020-05-15 18:56:01            SICKFC
# 3010         200923203  2020-04-01 13:04:22              SICK
# 8699         200851976  2020-03-25 10:14:24              SICK
# 11241        200753463  2020-03-15 19:01:48            CARDBR
# 8056         201111866  2020-04-20 12:43:12            TRAUMA
# 6318         200832488  2020-03-23 12:28:07              SICK
# 3221         200122042  2020-01-12 12:51:31             PD13C
# 4535         200551436  2020-02-24 10:09:19              CARD
# 7097         200252490  2020-01-25 15:04:39               EDP
# ...

# %%
## get basic overview of the data
type(ems2020_excerpt_df)
## what datatypes do the different columns hold?
ems2020_excerpt_df.info()
## how many rows and columns are there
ems2020_excerpt_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13117 entries, 0 to 13116
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   CAD_INCIDENT_ID                 13117 non-null  int64
#  1   INCIDENT_DATETIME               13117 non-null  object
#  2   INITIAL_CALL_TYPE               13117 non-null  object
#  3   INITIAL_SEVERITY_LEVEL_CODE     13117 non-null  int64
#  4   FINAL_CALL_TYPE                 13117 non-null  object
#  5   FINAL_SEVERITY_LEVEL_CODE       13117 non-null  int64
#  6   FIRST_ASSIGNMENT_DATETIME       13010 non-null  object
#  7   VALID_DISPATCH_RSPNS_TIME_INDC  13117 non-null  object
#  8   DISPATCH_RESPONSE_SECONDS_QY    13117 non-null  int64
#  9   FIRST_ACTIVATION_DATETIME       12988 non-null  object
#  10  FIRST_ON_SCENE_DATETIME         12533 non-null  object
#  11  VALID_INCIDENT_RSPNS_TIME_INDC  13117 non-null  object
# ...

# %%
## call the top 7 rows
ems2020_excerpt_df.head(7)
# Out:
#    CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 0        201101264  2020-04-19 10:25:47            INJMIN
# 1        200423766  2020-02-11 19:25:47              CARD
# 2        200434110  2020-02-12 21:36:52               UNC
# 3        201610121  2020-06-09 00:52:30              DRUG
# 4        200034112  2020-01-03 20:44:05              DRUG
# 5        200530247  2020-02-22 01:26:18              DRUG
# 6        200543279  2020-02-23 19:08:27               UNC
#
#    INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            7          INJMIN                          7
# 1                            3            SICK                          6
# 2                            2             UNC                          2
# 3                            4            DRUG                          4
# 4                            4            DRUG                          4
# ...

# %%
## call a sample of 10
ems2020_excerpt_df.sample(10)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 11213        201501656  2020-05-29 12:56:45               EDP
# 4750         201070991  2020-04-16 08:17:32               EDP
# 11228        201644080  2020-06-12 23:16:38              DRUG
# 1239         200583894  2020-02-27 20:19:02              SICK
# 12880        201111562  2020-04-20 11:26:38            SICKFC
# 5090         201771311  2020-06-25 10:24:17            INJURY
# 11619        200734187  2020-03-13 20:37:14            RESPIR
# 2072         200946294  2020-04-03 22:45:41            CDBRFC
# 4855         201600674  2020-06-08 05:52:59               EDP
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 11213                            7             EDP                          7
# 4750                             7            EDPC                          7
# ...

# %%
## call the bottom 6
ems2020_excerpt_df.tail(6)
# Out:
#        CAD_INCIDENT_ID    INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 13111        200870168  2020-03-27 00:42:59            INJURY
# 13112        200393407  2020-02-08 19:49:33            DIFFBR
# 13113        200034618  2020-01-03 22:51:33            INJURY
# 13114        200424355  2020-02-11 21:51:09              SICK
# 13115        201742708  2020-06-22 15:57:44            MVAINJ
# 13116        200865674  2020-03-26 19:33:19            DIFFFC
#
#        INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  FINAL_SEVERITY_LEVEL_CODE  \
# 13111                            5          INJURY                          5
# 13112                            2          DIFFBR                          2
# 13113                            5          INJURY                          5
# 13114                            6            SICK                          6
# 13115                            4          MVAINJ                          4
# ...

# %%
## Programmatically capture the 2245th FINAL_CALL_TYPE value and store in a variable.
value = ems2020_excerpt_df["FINAL_CALL_TYPE"].iat[2245]
value
# Out:
# 'UNC'

# %%
## import data here
pd.read_excel("data_raw/multi-data.xlsx")
# Out:
#        Serial Number    County License Type Code License Class Code  \
# 0            2000777    ALBANY                HL                242
# 1            1197749    NASSAU                CT                246
# 2            2149537  SULLIVAN                AX                122
# 3            1311950    QUEENS                 W                322
# 4            2217319    PUTNAM                TW                344
# ...              ...       ...               ...                ...
# 50135        1311238    QUEENS                AX                122
# 50136        3002671      ERIE                AX                122
# 50137        2209433  ONONDAGA                AX                128
# 50138        1312336     BRONX                CM                110
# 50139        2227379    ALBANY                WS                308
#
#        Certificate Number                    Premise Name  \
# 0                  912771           SUPER HOST HOTELS INC
# ...

# %%
## name the dataframe
cbp_df = pd.read_excel("data_raw/multi-data.xlsx", sheet_name = "CBP", skiprows = 6)

# %%
## call the top 15 rows
cbp_df.head(15)
# Out:
#                date_in            date_out  hours_in_custody     age_group  \
# 0  2017-01-20 00:10:00 2017-01-20 10:08:00          9.950000     6-8 years
# 1  2017-01-20 00:15:00 2017-01-24 17:30:00        113.233333     3-5 years
# 2  2017-01-20 00:22:00 2017-01-24 17:47:00        113.416667     3-5 years
# 3  2017-01-20 00:30:00 2017-01-21 06:35:00         30.083333   12-14 years
# 4  2017-01-20 00:30:00 2017-01-21 13:03:00         36.533333     3-5 years
# 5  2017-01-20 00:30:00 2017-01-21 15:30:00         38.983333  Under 1 year
# 6  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     6-8 years
# 7  2017-01-20 00:35:00 2017-01-20 15:14:00         14.633333     6-8 years
# 8  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667     3-5 years
# 9  2017-01-20 00:35:00 2017-01-21 11:52:00         35.266667    9-11 years
# 10 2017-01-20 00:45:00 2017-01-20 13:15:00         12.500000   15-18 years
# ...

# %%
## get basic overview of the data
type(cbp_df.info)
## what datatypes do the different columns hold?
cbp_df.info()
## how many rows and columns are there
cbp_df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95721 entries, 0 to 95720
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date_in           95721 non-null  datetime64[ns]
#  1   date_out          95223 non-null  datetime64[ns]
#  2   hours_in_custody  95506 non-null  float64
#  3   age_group         95716 non-null  object
#  4   gender            95721 non-null  object
#  5   citizenship       95721 non-null  object
#  6   border            95721 non-null  object
#  7   sector            95721 non-null  object
#  8   field_office      0 non-null      float64
# dtypes: datetime64[ns](2), float64(2), object(5)
# memory usage: 6.6+ MB
# (95721, 9)

# %%
## call the bottom 3
cbp_df.tail(3)
# Out:
#                   date_in            date_out  hours_in_custody    age_group  \
# 95718 2018-06-02 13:05:00 2018-06-05 23:35:00         82.483333    6-8 years
# 95719 2018-06-02 13:05:00 2018-06-04 00:54:00         35.800000  15-18 years
# 95720 2018-06-02 13:20:00 2018-06-06 07:27:00         90.100000    6-8 years
#
#        gender citizenship border      sector  field_office
# 95718  Female   GUATEMALA    SBO  (b)(7)(E )           NaN
# 95719    Male   GUATEMALA    SBO  (b)(7)(E )           NaN
# 95720    Male   GUATEMALA    SBO  (b)(7)(E )           NaN

# %%
## call a sample of 20
cbp_df.sample(20)
# Out:
#                   date_in            date_out  hours_in_custody     age_group  \
# 49365 2017-12-17 02:50:00 2017-12-27 11:36:00        248.750000   12-14 years
# 24778 2017-08-26 09:30:00 2017-08-26 12:10:00          2.650000   15-18 years
# 95664 2018-06-02 08:20:00 2018-06-06 12:32:00        100.183333    9-11 years
# 36045 2017-10-27 18:30:00 2017-11-01 13:25:00        114.900000  Under 1 year
# 89900 2018-05-18 19:00:00 2018-05-23 11:14:00        112.216667     1-2 years
# 69765 2018-03-17 17:05:00 2018-03-20 10:53:00         65.783333    9-11 years
# 43193 2017-11-25 19:50:00 2017-11-28 11:14:00         63.383333    9-11 years
# 9580  2017-04-13 22:30:00 2017-04-14 15:15:00         16.733333   12-14 years
# 67746 2018-03-10 19:20:00 2018-03-11 10:46:00         15.416667   15-18 years
# 62837 2018-02-18 00:18:00 2018-02-18 09:59:00          9.666667   15-18 years
# 32215 2017-10-07 21:45:00 2017-10-09 14:44:00         40.966667   15-18 years
# ...

# %%
## Programmatically capture the 8th hours_in_custody value and store in a variable.
value = cbp_df["hours_in_custody"].iat[7]

# %%
value
# Out:
# 14.6333333333333
